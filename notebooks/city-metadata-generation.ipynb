# %%
import pprint
import json
import time
import random

# %%
from tqdm.auto import tqdm
import pandas
import requests
from requests_ntlm import HttpNtlmAuth
from bs4 import BeautifulSoup
import numpy

# %%
secrets = json.load(open("/home/jovyan/secrets/secrets.json"))

# %% [markdown]
# ## Reading in Metadata Spreadsheet

# %%
city_metadata_df = pandas.read_excel("MetadataFields_Descriptors.xlsx")

# %%
city_metadata_df = city_metadata_df[
    ['Category', 'Field Name', 'Description','Acceptable Values']
]

# %%
city_metadata_df.Category = (
    city_metadata_df.Category.fillna(method="ffill")
                    .str.split("\n")
                    .apply(lambda x: x[0])
)

# %% [markdown]
# ## Core Schema

# %%
core_filter = city_metadata_df.Category == "Core Fields"

# %%
fields_urlified = (
    city_metadata_df.loc[core_filter, "Field Name"]
                    .str.lower()
                    .str.replace(" ", "_")
                    .str.replace(r'\W', "")
)

metadata_df = pandas.DataFrame({
    "field_name": fields_urlified,
    "help_text": city_metadata_df.loc[core_filter, "Description"].str.split("\n").apply(lambda x: x[0]),
    "required": True,
    'label': city_metadata_df.loc[core_filter, "Field Name"].str.strip()
}).set_index('label')

# %% [markdown]
# ### Overrides

# %%
metadata_df
# Out:
#                                                                       field_name  \
# label
# Unique ID                                                              unique_id
# Data Set Name                                                      data_set_name
# Data Set Description (Including purpose)  data_set_description_including_purpose
# Data Quality                                                        data_quality
# Update Frequency                                                update_frequency
# Data Access Rights                                            data_access_rights
# Restricted Reason                                              restricted_reason
# Data Format                                                          data_format
# Data Steward                                                        data_steward
# DS/TR Branch                                                         dstr_branch
# DS/TR Department                                                 dstr_department
# DS/TR Directorate                                               dstr_directorate
# Data Contact                                                       data_contact_
# Data Custodian                                                    data_custodian
# Host System ID                                                    host_system_id
# Spatial Coverage                                                spatial_coverage
# Temporal Coverage                                              temporal_coverage
#
#                                                                                   help_text  \
# label
# Unique ID                                                                 Dataset unique ID
# Data Set Name                                                  A name given to the dataset.
# Data Set Description (Including purpose)                          A summary of the dataset.
# Data Quality                                       Subjective assesment of dataset quality.
# Update Frequency                                 How often is data updated in the data set?
# Data Access Rights                        Indicates the classification of the dataset in...
# Restricted Reason                         To be completed if the data is indicated as Re...
# Data Format                               Provides an indication of the interoperable st...
# Data Steward                              Indicates the individual who assumes business ...
# DS/TR Branch                              Indicates the organisational unit (branch) of ...
# DS/TR Department                          Indicates the organisational unit (department)...
# DS/TR Directorate                         Indicates the organisational unit (directorate...
# Data Contact                              Indicates the official who works most closely ...
# Data Custodian                            Indicates the individual who is responsible fo...
# Host System ID                            Unique ID of the appilication in which the dat...
# Spatial Coverage                                 Is there any spatial data in this dataset?
# Temporal Coverage                               Is there any temporal data in this dataset?
#
#                                           required
# label
# Unique ID                                     True
# Data Set Name                                 True
# Data Set Description (Including purpose)      True
# Data Quality                                  True
# Update Frequency                              True
# Data Access Rights                            True
# Restricted Reason                             True
# Data Format                                   True
# Data Steward                                  True
# DS/TR Branch                                  True
# DS/TR Department                              True
# DS/TR Directorate                             True
# Data Contact                                  True
# Data Custodian                                True
# Host System ID                                True
# Spatial Coverage                              True
# Temporal Coverage                             True

# %%
choices_dict = {}

# %%
metadata_df.loc["Unique ID", "field_name"] = "name"
metadata_df.loc["Unique ID", "preset"] = "dataset_slug"

# %%
metadata_df.loc["Data Set Name", "field_name"] = "name"
metadata_df.loc["Data Set Name", "preset"] = "title"

# %%
metadata_df.loc["Data Set Description (Including purpose)", "field_name"] = "data_set_description"
metadata_df.loc["Data Set Description (Including purpose)", "form_snippet"] = "markdown.html"

# %%
metadata_df.loc["Update Frequency", "preset"] = "select"
metadata_df.loc["Update Frequency", "choices"] = True
choices_dict["Update Frequency"] = ["Historical", "Event-based"]

# %%
# Add reference to Data Access SOP to help with classification
metadata_df.loc["Data Access Rights", "preset"] = "select"
metadata_df.loc["Data Access Rights", "choices"] = True
choices_dict["Data Access Rights"] = ["Open Public", "Internal Open", "Internal Restricted", "Secret"]

# %%
metadata_df.loc["Restricted Reason", "required"] = False # ToDo - add validator that inspects the data access rights field

# %%
metadata_df.loc["Data Format", "preset"] = "resource_format_autocomplete"
metadata_df.loc["Data Format", "required"] = False

# %%
metadata_df.loc["Data Steward", "field_name"] = "maintainer"
metadata_df.loc["Data Steward", "display_property"] = "dc:contributor"

# %%
metadata_df.loc["DS/TR Directorate", "field_name"] = "owner_org"
metadata_df.loc["DS/TR Directorate", "preset"] = "dataset_organization"

# %%
metadata_df.loc["DS/TR Department", "preset"] = "select"
metadata_df.loc["DS/TR Department", "choices_helper"] = "cct_metadata_get_departments"
metadata_df.loc["DS/TR Department", "validators"] = "cct_metadata_check_department"

# %%
metadata_df.loc["DS/TR Branch", "preset"] = "select"
metadata_df.loc["DS/TR Branch", "choices_helper"] = "cct_metadata_get_branches"
metadata_df.loc["DS/TR Branch", "validators"] = "cct_metadata_check_branch"

# %%
metadata_df.loc["Data Custodian", "field_name"] = "publisher"
metadata_df.loc["Data Custodian", "display_property"] = "dc:publisher"

# %%
metadata_df.loc["Spatial Coverage", "preset"] = "select"
choices_dict["Spatial Coverage"] = ["NA", "<1m²", "<10m²", "<100m²", "<1km²", "<10km²", "<100km²", "<1000km²", "<10000km²"]

# %%
metadata_df.loc["Temporal Coverage", "preset"] = "boolean_select"

# %%
metadata_df.loc["Temporal Coverage Start", "field_name"] = "temporal_coverage_start"
metadata_df.loc["Temporal Coverage Start", "help_text"] = "Start date of temporal coverage."
metadata_df.loc["Temporal Coverage Start", "preset"] = "date"

# %%
metadata_df.loc["Temporal Coverage End", "field_name"] = "temporal_coverage_end"
metadata_df.loc["Temporal Coverage End", "help_text"] = "End date of temporal coverage."
metadata_df.loc["Temporal Coverage End", "preset"] = "date"

# %% [markdown]
# ## Outputting Schema

# %%
metadata_schema = {
  "scheming_version": 1,
  "dataset_type": "dataset",
  "about": "Schema for the City of Cape Town",
  "about_url": "http://github.com/ckan/ckanext-scheming",
    "resource_fields": [
    {
      "field_name": "url",
      "label": "URL",
      "preset": "resource_url_upload"
    },
    {
      "field_name": "name",
      "label": "Name",
      "form_placeholder": "eg. January 2020 Service Requests"
    },
    {
      "field_name": "description",
      "label": "Description",
      "form_snippet": "markdown.html",
      "form_placeholder": "Some useful notes about the data"
    },
    {
      "field_name": "format",
      "label": "Format",
      "preset": "resource_format_autocomplete"
    }
    ]
}

# %%
metadata_schema["dataset_fields"] = metadata_df.reset_index().to_dict(orient="records")

# %%
for dataset_dict in metadata_schema["dataset_fields"]:
    # Cleaning up nan values
    keys_to_remove = [
        key
        for key, value in dataset_dict.items()
        if pandas.isna(value)
    ]
    
    for key in keys_to_remove:
        del dataset_dict[key]
    
    # Merging in choices
    choices = choices_dict.get(dataset_dict["label"], None)
    if choices is not None:
        dataset_dict["choices"] = [
            {"label": label, "value": label.lower().replace(" ","_")}
            for label in choices
        ]

# %%
metadata_schema["dataset_fields"]
# Out:
# [{'label': 'Unique ID',
#   'field_name': 'name',
#   'help_text': 'Dataset unique ID',
#   'required': True,
#   'preset': 'dataset_slug'},
#  {'label': 'Data Set Name',
#   'field_name': 'name',
#   'help_text': 'A name given to the dataset.',
#   'required': True,
#   'preset': 'title'},
#  {'label': 'Data Set Description (Including purpose)',
#   'field_name': 'data_set_description',
#   'help_text': 'A summary of the dataset.',
#   'required': True,
#   'form_snippet': 'markdown.html'},
#  {'label': 'Data Quality',
#   'field_name': 'data_quality',
#   'help_text': 'Subjective assesment of dataset quality.',
#   'required': True},
#  {'label': 'Update Frequency',
#   'field_name': 'update_frequency',
#   'help_text': 'How often is data updated in the data set?',
#   'required': True,
#   'preset': 'select',
#   'choices': [{'label': 'Historical', 'value': 'historical'},
#    {'label': 'Event-based', 'value': 'event-based'}]},
#  {'label': 'Data Access Rights',
#   'field_name': 'data_access_rights',
#   'help_text': 'Indicates the classification of the dataset in terms of access',
#   'required': True,
#   'preset': 'select',
#   'choices': [{'label': 'Open Public', 'value': 'open_public'},
#    {'label': 'Internal Open', 'value': 'internal_open'},
#    {'label': 'Internal Restricted', 'value': 'internal_restricted'},
#    {'label': 'Secret', 'value': 'secret'}]},
#  {'label': 'Restricted Reason',
#   'field_name': 'restricted_reason',
#   'help_text': 'To be completed if the data is indicated as Restricted',
#   'required': False},
#  {'label': 'Data Format',
#   'field_name': 'data_format',
#   'help_text': 'Provides an indication of the interoperable structure of the data as reflected by the primary file format in which the system exports data',
#   'required': False,
#   'preset': 'resource_format_autocomplete'},
#  {'label': 'Data Steward',
#   'field_name': 'maintainer',
#   'help_text': 'Indicates the individual who assumes business accountability for the dataset in relation to aspects such as access, quality, integrity, completeness.',
#   'required': True,
#   'display_property': 'dc:contributor'},
#  {'label': 'DS/TR Branch',
#   'field_name': 'dstr_branch',
#   'help_text': 'Indicates the organisational unit (branch) of the data steward',
#   'required': True,
#   'preset': 'select',
#   'choices_helper': 'cct_metadata_get_branches',
#   'validators': 'cct_metadata_check_branch'},
#  {'label': 'DS/TR Department',
#   'field_name': 'dstr_department',
#   'help_text': 'Indicates the organisational unit (department) of the data steward',
#   'required': True,
#   'preset': 'select',
#   'choices_helper': 'cct_metadata_get_departments',
#   'validators': 'cct_metadata_check_department'},
#  {'label': 'DS/TR Directorate',
#   'field_name': 'owner_org',
#   'help_text': 'Indicates the organisational unit (directorate) of the data steward',
#   'required': True,
#   'preset': 'dataset_organization'},
#  {'label': 'Data Contact',
#   'field_name': 'data_contact_',
#   'help_text': 'Indicates the official who works most closely with and can best provide additional information about the data and metadata',
#   'required': True},
#  {'label': 'Data Custodian',
#   'field_name': 'publisher',
#   'help_text': 'Indicates the individual who is responsible for the technical management of the date e.g. the hosting and serving of the data',
#   'required': True,
#   'display_property': 'dc:publisher'},
#  {'label': 'Host System ID',
#   'field_name': 'host_system_id',
#   'help_text': 'Unique ID of the appilication in which the data is stored (primary/source system)',
#   'required': True},
#  {'label': 'Spatial Coverage',
#   'field_name': 'spatial_coverage',
#   'help_text': 'Is there any spatial data in this dataset?',
#   'required': True,
#   'preset': 'select',
#   'choices': [{'label': 'NA', 'value': 'na'},
#    {'label': '<1m²', 'value': '<1m²'},
#    {'label': '<10m²', 'value': '<10m²'},
#    {'label': '<100m²', 'value': '<100m²'},
#    {'label': '<1km²', 'value': '<1km²'},
#    {'label': '<10km²', 'value': '<10km²'},
#    {'label': '<100km²', 'value': '<100km²'},
#    {'label': '<1000km²', 'value': '<1000km²'},
#    {'label': '<10000km²', 'value': '<10000km²'}]},
#  {'label': 'Temporal Coverage',
#   'field_name': 'temporal_coverage',
#   'help_text': 'Is there any temporal data in this dataset?',
#   'required': True,
#   'preset': 'boolean_select'},
#  {'label': 'Temporal Coverage Start',
#   'field_name': 'temporal_coverage_start',
#   'help_text': 'Start date of temporal coverage.',
#   'preset': 'date'},
#  {'label': 'Temporal Coverage End',
#   'field_name': 'temporal_coverage_end',
#   'help_text': 'End date of temporal coverage.',
#   'preset': 'date'}]

# %%
with open("cct_metadata.json", "w") as metadata_json_file:
    json.dump(metadata_schema, metadata_json_file)

# %% [markdown]
# ## Getting list of City Departments

# %%
proxies = {
    'http':  f"http://internet.capetown.gov.za:8080",
    'https': f"http://internet.capetown.gov.za:8080",
}

# %%
URL = "http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/"

# %%
# Reading the page contents
DIRECTORATES_PAGE = "Directorates.aspx"

# %%
def setup_session():
    http = requests.Session()
    http.proxies = proxies
    auth = HttpNtlmAuth(f'CAPETOWN\\{secrets["proxy"]["username"]}', secrets["proxy"]["password"])
    http.auth = auth

    headers = {'Proxy-Authorization': requests.auth._basic_auth_str(secrets["proxy"]["username"], secrets["proxy"]["password"])}
    http.headers = headers
    
    return http

# %%
def get_divs(link, div_id, session):
    
    divs = []
    tries = 0
    while tries < 2:
        try:            
            resp = session.get(link)
            soup = BeautifulSoup(resp.text, 'html.parser')
            divs = soup.find_all("div", {"id": div_id})
            tries = 2
            
        except Exception as e:
            print(f"failed for '{link}'")
            print(f'failed because {e.__class__}: "{e}"')
            session = setup_session()
            
            tries += 1
            time.sleep(5)
        
    return divs

# %%
directorate_divs = get_divs(URL + DIRECTORATES_PAGE, "directorate", setup_session())

directorate_dicts = [
    {
        "name": direc.find('a').contents[0].strip().lower().title(), 
        "link": URL + direc.find('a').get('href'),
    }
    for direc in tqdm(directorate_divs)
]
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Directorates.aspx HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Directorates.aspx HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Directorates.aspx HTTP/1.1" 200 80021
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
session = setup_session()
for directorate_dict in tqdm(directorate_dicts):
    if directorate_dict.get("departments", 0) == 0:
        directorate_dict["departments"] = [
            {
                "name": dept.find('a').contents[0].strip().lower().title(),
                "link": URL + dept.find('a').get('href'),
            }
            for dept in get_divs(directorate_dict["link"], "department", session)
        ]
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000506 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000506 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000506 HTTP/1.1" 200 77055
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70007527 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70007527 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70007527 HTTP/1.1" 200 80390
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010484 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010484 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010484 HTTP/1.1" 200 77751
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010519 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010519 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010519 HTTP/1.1" 200 73334
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000968 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000968 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70000968 HTTP/1.1" 200 78242
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015226 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015226 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015226 HTTP/1.1" 200 76445
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010494 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010494 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010494 HTTP/1.1" 200 73225
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70002692 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70002692 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70002692 HTTP/1.1" 200 77828
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015225 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015225 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70015225 HTTP/1.1" 200 76245
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001876 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001876 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001876 HTTP/1.1" 200 76496
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010475 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010475 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70010475 HTTP/1.1" 200 82013
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001882 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001882 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Departments.aspx?Directorate=70001882 HTTP/1.1" 200 74111

# %%
for directorate_dict in tqdm(directorate_dicts):
    session = setup_session()
    for department_dict in directorate_dict["departments"]:
        if directorate_dict.get("branches", 0) == 0:
            department_dict["branches"] = [
                {
                    "name": dept.find('a').contents[0].strip().lower().title(),
                    "link": URL + dept.find('a').get('href'),
                }
                for dept in get_divs(department_dict["link"], "branch", session)
            ]
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70011193 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70011193 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70011193 HTTP/1.1" 200 70722
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70000507 HTTP/1.1" 200 83712
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70004118 HTTP/1.1" 200 70607
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70010409 HTTP/1.1" 200 72091
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70000636 HTTP/1.1" 200 75495
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70010408 HTTP/1.1" 200 74134
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70010627 HTTP/1.1" 200 76560
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70007452 HTTP/1.1" 200 239784
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000506&Department=70002004 HTTP/1.1" 200 72837
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70001033 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70001033 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70001033 HTTP/1.1" 200 73386
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70013174 HTTP/1.1" 200 72799
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70002005 HTTP/1.1" 200 72898
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70002398 HTTP/1.1" 200 76132
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70002002 HTTP/1.1" 200 77068
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70001059 HTTP/1.1" 200 73610
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70002012 HTTP/1.1" 200 77542
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70001899 HTTP/1.1" 200 75090
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70012698 HTTP/1.1" 200 70692
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70010575 HTTP/1.1" 200 73130
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70010518 HTTP/1.1" 200 72991
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70007575 HTTP/1.1" 200 73427
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70007527&Department=70011379 HTTP/1.1" 200 70589
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70008478 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70008478 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70008478 HTTP/1.1" 200 74991
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70001900 HTTP/1.1" 200 73005
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70010510 HTTP/1.1" 200 70663
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70010504 HTTP/1.1" 200 72914
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70010509 HTTP/1.1" 200 70693
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70013508 HTTP/1.1" 200 70704
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70011181 HTTP/1.1" 200 70643
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70000178 HTTP/1.1" 200 75032
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70010502 HTTP/1.1" 200 74726
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010484&Department=70010511 HTTP/1.1" 200 70667
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70012427 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70012427 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70012427 HTTP/1.1" 200 70651
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70003725 HTTP/1.1" 200 76459
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70015183 HTTP/1.1" 200 70275
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010519&Department=70010383 HTTP/1.1" 200 74930
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70000983 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70000983 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70000983 HTTP/1.1" 200 73468
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70004177 HTTP/1.1" 200 74158
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70002877 HTTP/1.1" 200 72889
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70010391 HTTP/1.1" 200 70468
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70001029 HTTP/1.1" 200 72718
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70008775 HTTP/1.1" 200 72001
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70002254 HTTP/1.1" 200 73372
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70001884 HTTP/1.1" 200 75698
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70002879 HTTP/1.1" 200 70574
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70001885 HTTP/1.1" 200 73535
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70000968&Department=70000975 HTTP/1.1" 200 74242
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70001032 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70001032 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70001032 HTTP/1.1" 200 74848
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70007831 HTTP/1.1" 200 73699
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70007832 HTTP/1.1" 200 72645
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70015412 HTTP/1.1" 200 71293
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70006653 HTTP/1.1" 200 73416
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70015612 HTTP/1.1" 200 70247
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70015611 HTTP/1.1" 200 72700
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70015227 HTTP/1.1" 200 70538
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015226&Department=70015610 HTTP/1.1" 200 72084
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70008893 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70008893 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70008893 HTTP/1.1" 200 71313
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70010606 HTTP/1.1" 200 74160
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70010516 HTTP/1.1" 200 75080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010494&Department=70013474 HTTP/1.1" 200 71602
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000577 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000577 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000577 HTTP/1.1" 200 77759
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70007502 HTTP/1.1" 200 74135
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70004431 HTTP/1.1" 200 70666
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000561 HTTP/1.1" 200 92364
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70008801 HTTP/1.1" 200 70636
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000536 HTTP/1.1" 200 75525
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70010398 HTTP/1.1" 200 73386
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70000578 HTTP/1.1" 200 72636
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70017825 HTTP/1.1" 200 70246
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70002692&Department=70004089 HTTP/1.1" 200 72690
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70001905 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70001905 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70001905 HTTP/1.1" 200 74981
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70015385 HTTP/1.1" 200 72074
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70015384 HTTP/1.1" 200 70740
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70000144 HTTP/1.1" 200 74263
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70015228 HTTP/1.1" 200 70661
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70015383 HTTP/1.1" 200 72425
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70010415 HTTP/1.1" 200 72819
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70015225&Department=70001903 HTTP/1.1" 200 74134
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70016311 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70016311 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70016311 HTTP/1.1" 200 70599
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70007848 HTTP/1.1" 200 74167
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70001031 HTTP/1.1" 200 72049
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70010636 HTTP/1.1" 200 72087
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70007954 HTTP/1.1" 200 72676
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70015229 HTTP/1.1" 200 70562
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70007950 HTTP/1.1" 200 74144
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70007953 HTTP/1.1" 200 73454
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001876&Department=70007849 HTTP/1.1" 200 74769
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010479 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010479 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010479 HTTP/1.1" 200 99220
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010476 HTTP/1.1" 200 83588
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010477 HTTP/1.1" 200 87173
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010478 HTTP/1.1" 200 86857
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70006307 HTTP/1.1" 200 71381
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70000003 HTTP/1.1" 200 72643
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002125 HTTP/1.1" 200 76259
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010482 HTTP/1.1" 200 71625
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010481 HTTP/1.1" 200 70636
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70008477 HTTP/1.1" 200 71339
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002773 HTTP/1.1" 200 74967
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002772 HTTP/1.1" 200 78281
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002774 HTTP/1.1" 200 74157
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010604 HTTP/1.1" 200 70640
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002050 HTTP/1.1" 200 77914
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70010483 HTTP/1.1" 200 72855
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70010475&Department=70002800 HTTP/1.1" 200 70669
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): internet.capetown.gov.za:8080
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70002427 HTTP/1.1" 401 16
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70002427 HTTP/1.1" 401 0
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70002427 HTTP/1.1" 200 70515
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70004111 HTTP/1.1" 200 71344
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70000331 HTTP/1.1" 200 76875
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70002009 HTTP/1.1" 200 72149
# DEBUG:urllib3.connectionpool:http://internet.capetown.gov.za:8080 "GET http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/Branches.aspx?Directorate=70001882&Department=70000205 HTTP/1.1" 200 83010

# %%
pprint.pprint(directorate_dicts)
# Out:
# [{'departments': [{'branches': [],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70011193',
#                    'name': 'Administration'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70010441',
#                                  'name': 'Area Central'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70010440',
#                                  'name': 'Area East'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70010439',
#                                  'name': 'Area North'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70010442',
#                                  'name': 'Area South'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018457',
#                                  'name': 'Epwp -Epwp H/O Admin Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018042',
#                                  'name': 'Epwp -Sa Admin: Albow Gardens'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018401',
#                                  'name': 'Epwp -Sa Admin: Delft'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018421',
#                                  'name': 'Epwp -Sa Admin: Eersterivier'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018043',
#                                  'name': 'Epwp -Sa Admin: Manenberg'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018044',
#                                  'name': 'Epwp -Sa Admin: Parkwood'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018045',
#                                  'name': 'Epwp -Sa Admin: Tafelsig'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018264',
#                                  'name': 'Epwp -Substance Abuse Admin.Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018264',
#                                  'name': 'Epwp -Substance Abuse Admin.Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018265',
#                                  'name': 'Epwp -Substance Abuse: Students'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018266',
#                                  'name': 'Epwp -Substance Abuse: Students'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70018415',
#                                  'name': 'Epwp -W/A: Goodwood Clinic'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70002482',
#                                  'name': 'Finance (Health)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70000532',
#                                  'name': 'Specialised Health Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000507&Branch=70000535',
#                                  'name': 'Support: City Health'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70000507',
#                    'name': 'City Health'},
#                   {'branches': [],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70004118',
#                    'name': 'Finance (Comserv)'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010409&Branch=70017075',
#                                  'name': 'Ohs And Eap'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010409&Branch=70015807',
#                                  'name': 'Workforce Performance Management'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70010409',
#                    'name': 'Hr Business Partner (Comserv)'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70000648',
#                                  'name': 'Area Central'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70000609',
#                                  'name': 'Area East'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70000582',
#                                  'name': 'Area North'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70000681',
#                                  'name': 'Area South'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70004115',
#                                  'name': 'Finance (Libraries)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70010628',
#                                  'name': 'Specialized Operations'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70000636&Branch=70004116',
#                                  'name': 'Support Services : Libraries'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70000636',
#                    'name': 'Library And Information Services'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010408&Branch=70012425',
#                                  'name': 'Administration'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010408&Branch=70016694',
#                                  'name': 'Finance'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010408&Branch=70002519',
#                                  'name': 'Gis, Information And Property '
#                                          'Management'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010408&Branch=70008425',
#                                  'name': 'Planning And Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010408&Branch=70012426',
#                                  'name': 'Project Management Office'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70010408',
#                    'name': 'Planning & Development & Pmo'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010635',
#                                  'name': 'Recreation And Parks Support '
#                                          'Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010633',
#                                  'name': 'Recreation And Parks: Area Central'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010632',
#                                  'name': 'Recreation And Parks: Area East'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010631',
#                                  'name': 'Recreation And Parks: Area North'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010634',
#                                  'name': 'Recreation And Parks: Area South'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010629',
#                                  'name': 'Recreation And Parks: Centralised '
#                                          'Operations And Programmes'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70010630',
#                                  'name': 'Recreation And Parks: Facilities '
#                                          'Maintenance And Project Management'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70010627&Branch=70004122',
#                                  'name': 'Recreation And Parks: Finance '
#                                          'Support'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70000506&Department=70010627',
#                    'name': 'Recreation And Parks'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70010405',
#                                  'name': 'Area Central Sdecd'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70010404',
#                                  'name': 'Area East Sdecd'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70010403',
#                                  'name': 'Area North Sdecd'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70010406',
#                                  'name': 'Area South Sdecd'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70002054',
#                                  'name': 'Arts And Culture'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70010407',
#                                  'name': 'Centralised Operations, Programmes & '
#                                          'Pmo'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015078',
#                                  'name': 'Epwp -1 Support Area Central'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015080',
#                                  'name': 'Epwp -1 Support Area North'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017229',
#                                  'name': 'Epwp -19/20 Wfc Project Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016984',
#                                  'name': 'Epwp -19/20 Wfc Ward 10'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016991',
#                                  'name': 'Epwp -19/20 Wfc Ward 10'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016887',
#                                  'name': 'Epwp -19/20 Wfc Ward 106'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016992',
#                                  'name': 'Epwp -19/20 Wfc Ward 12'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016993',
#                                  'name': 'Epwp -19/20 Wfc Ward 28'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016994',
#                                  'name': 'Epwp -19/20 Wfc Ward 30'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016995',
#                                  'name': 'Epwp -19/20 Wfc Ward 31'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016883',
#                                  'name': 'Epwp -19/20 Wfc Ward 39'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016884',
#                                  'name': 'Epwp -19/20 Wfc Ward 44'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016885',
#                                  'name': 'Epwp -19/20 Wfc Ward 46'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016886',
#                                  'name': 'Epwp -19/20 Wfc Ward 50'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017925',
#                                  'name': 'Epwp -2019/20 Is Phase 2'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018104',
#                                  'name': 'Epwp -2019/20 Saa Ward 106'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018105',
#                                  'name': 'Epwp -2019/20 Ward 13'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018004',
#                                  'name': 'Epwp -2019/20 Wfc Support 2'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018005',
#                                  'name': 'Epwp -2019/20 Wfc Support 2'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018103',
#                                  'name': 'Epwp -2019/20 Wfc Ward 40'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017554',
#                                  'name': 'Epwp -After School Game Changer'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017555',
#                                  'name': 'Epwp -After School Game Changer'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017556',
#                                  'name': 'Epwp -After School Game Changer 2'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017557',
#                                  'name': 'Epwp -After School Game Changer 3'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017558',
#                                  'name': 'Epwp -After School Game Changer 4'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014874',
#                                  'name': 'Epwp -Alo - Shay'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014874',
#                                  'name': 'Epwp -Alo - Shay'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015143',
#                                  'name': 'Epwp -Alo - Shay 1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015143',
#                                  'name': 'Epwp -Alo - Shay 1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014975',
#                                  'name': 'Epwp -Brian F South'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016989',
#                                  'name': "Epwp -Clo'S - Daniel"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016987',
#                                  'name': "Epwp -Clo'S - Msk"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70016990',
#                                  'name': "Epwp -Clo'S - Shay"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018422',
#                                  'name': 'Epwp -Community And Cultural '
#                                          'Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018423',
#                                  'name': 'Epwp -Community And Cultural '
#                                          'Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018424',
#                                  'name': 'Epwp -Community And Cultural '
#                                          'Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018575',
#                                  'name': 'Epwp -Community And Cultural '
#                                          'Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018576',
#                                  'name': 'Epwp -Community And Cultural '
#                                          'Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70013405',
#                                  'name': 'Epwp -Culemborg Safe Space Law '
#                                          'Enforceme'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014979',
#                                  'name': 'Epwp -Deon Assets'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015123',
#                                  'name': 'Epwp -East Admin Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015123',
#                                  'name': 'Epwp -East Admin Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018126',
#                                  'name': 'Epwp -Ecd Resource Libraries'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018127',
#                                  'name': 'Epwp -Ecd Resource Libraries'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018360',
#                                  'name': 'Epwp -Ecd South: Cafda'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018352',
#                                  'name': 'Epwp -Ecd South: Cuba Heights'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018358',
#                                  'name': 'Epwp -Ecd South: Eagle Park'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018356',
#                                  'name': 'Epwp -Ecd South: Grassy Park'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018353',
#                                  'name': 'Epwp -Ecd South: Lavender Hill'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018351',
#                                  'name': 'Epwp -Ecd South: Lotus River'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018361',
#                                  'name': 'Epwp -Ecd South: Montague Village'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018363',
#                                  'name': 'Epwp -Ecd South: New Horizons'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018362',
#                                  'name': 'Epwp -Ecd South: Ocean View'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018099',
#                                  'name': 'Epwp -Ecd South: Ottery'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018098',
#                                  'name': 'Epwp -Ecd South: Parkwood'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018354',
#                                  'name': 'Epwp -Ecd South: Pelican Park'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018350',
#                                  'name': 'Epwp -Ecd South: Retreat'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018359',
#                                  'name': 'Epwp -Ecd South: Seawinds'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018355',
#                                  'name': 'Epwp -Ecd South: Steenberg'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018357',
#                                  'name': 'Epwp -Ecd South: Village Heights'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018142',
#                                  'name': 'Epwp -Ecd South: Ward 33'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018143',
#                                  'name': 'Epwp -Ecd South: Ward 34/80'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018144',
#                                  'name': 'Epwp -Ecd South: Ward 35'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018145',
#                                  'name': 'Epwp -Ecd South: Ward 36'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018283',
#                                  'name': 'Epwp -Ecd South: Ward 36'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018147',
#                                  'name': 'Epwp -Ecd South: Ward 75/76'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018139',
#                                  'name': 'Epwp -Ecd South: Ward 79'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018140',
#                                  'name': 'Epwp -Ecd South: Ward 81'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018141',
#                                  'name': 'Epwp -Ecd South: Ward 82'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018146',
#                                  'name': 'Epwp -Ecd South: Ward 88'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018033',
#                                  'name': 'Epwp -Ecd-Holiday Program'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018190',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Delft'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018187',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr '
#                                          'Eersteriver'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018189',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Khaya'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018191',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr '
#                                          'Kuilsriver'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018192',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Macassar'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018194',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Mfuleni'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018186',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Sir Lowry '
#                                          'Pass'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018193',
#                                  'name': 'Epwp -Epwp-Sdecd East Ywr Strand'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018544',
#                                  'name': 'Epwp -Facility Maintenance'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018545',
#                                  'name': 'Epwp -Facility Maintenance'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018546',
#                                  'name': 'Epwp -Facility Maintenance1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017649',
#                                  'name': 'Epwp -Info.Marikana'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017529',
#                                  'name': 'Epwp -Info.Marikana'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018260',
#                                  'name': 'Epwp -Informal Settlement Ae '
#                                          'Driftsands'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018261',
#                                  'name': 'Epwp -Informal Settlement Ae '
#                                          'Kalkfontein'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018262',
#                                  'name': 'Epwp -Informal Settlement Ae '
#                                          'Khayelitsa'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018263',
#                                  'name': 'Epwp -Informal Settlement Ae '
#                                          'Khayelitsha'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018258',
#                                  'name': 'Epwp -Informal Settlement Ae '
#                                          'Mfuleni'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018259',
#                                  'name': 'Epwp -Informal Settlement Ae Sir '
#                                          'Lowry P'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018135',
#                                  'name': 'Epwp -Informal Settlement '
#                                          'Khayelitsa'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018461',
#                                  'name': "Epwp -Men'S Emp: Camp Joy"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018458',
#                                  'name': "Epwp -Men'S Emp: Ctdcc"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018459',
#                                  'name': "Epwp -Men'S Emp: Mustadafin"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018460',
#                                  'name': "Epwp -Men'S Emp: Ymca"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018625',
#                                  'name': "Epwp -Men'S Empowerment"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018626',
#                                  'name': "Epwp -Men'S Empowerment"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018627',
#                                  'name': "Epwp -Men'S Empowerment"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70018628',
#                                  'name': "Epwp -Men'S Empowerment"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014816',
#                                  'name': 'Epwp -Project Support'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017755',
#                                  'name': 'Epwp -Sdecd East Blackheath'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017755',
#                                  'name': 'Epwp -Sdecd East Blackheath'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017756',
#                                  'name': 'Epwp -Sdecd East Happy Valley'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017757',
#                                  'name': 'Epwp -Sdecd East Mandalay'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017753',
#                                  'name': 'Epwp -Sdecd East Ywr Khayelitsha '
#                                          'Harare'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017753',
#                                  'name': 'Epwp -Sdecd East Ywr Khayelitsha '
#                                          'Harare'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017754',
#                                  'name': 'Epwp -Sdecd East Ywr Khayelitsha '
#                                          'Site B'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017754',
#                                  'name': 'Epwp -Sdecd East Ywr Khayelitsha '
#                                          'Site B'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017752',
#                                  'name': 'Epwp -Sdecd East Ywr Khyalitsha'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017752',
#                                  'name': 'Epwp -Sdecd East Ywr Khyalitsha'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70014978',
#                                  'name': 'Epwp -Shiobhan - Comms'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015952',
#                                  'name': 'Epwp -Street People 107 Call Takers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70015953',
#                                  'name': 'Epwp -Street People 107 Call Takers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017560',
#                                  'name': 'Epwp -Street People Economics 1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017572',
#                                  'name': 'Epwp -Street People Economics 1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017559',
#                                  'name': 'Epwp -Street People Economics 1'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017631',
#                                  'name': 'Epwp -Street People Economics 10'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017569',
#                                  'name': 'Epwp -Street People Economics 10'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017632',
#                                  'name': 'Epwp -Street People Economics 11'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017570',
#                                  'name': 'Epwp -Street People Economics 11'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017571',
#                                  'name': 'Epwp -Street People Economics 12'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70000506&Department=70007452&Branch=70017633',
#                                  'name': 'Epwp -Street People Economics 12'},
# ...
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002774&Branch=70004170',
#                                  'name': "Community Liaison (M'Plain)"},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002774&Branch=70007904',
#                                  'name': 'Development Coordinator (M/Plain)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002774&Branch=70004726',
#                                  'name': 'Economic Development (Mitchells '
#                                          'Plain)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002774&Branch=70004168',
#                                  'name': 'Project Support & Coordination '
#                                          "(M'Plain)"}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70010475&Department=70002774',
#                    'name': 'Murp Area South'},
#                   {'branches': [],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70010475&Department=70010604',
#                    'name': 'Pmo (Um)'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016178',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016178',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016208',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016208',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016209',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016209',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016209',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016285',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70016285',
#                                  'name': 'Epwp -Public Participation '
#                                          'Fieldworkers'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70002050&Branch=70004093',
#                                  'name': 'Regional Operations'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70010475&Department=70002050',
#                    'name': 'Public Participation'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70010483&Branch=70004501',
#                                  'name': 'Departmental Support Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70010483&Branch=70002745',
#                                  'name': 'Inter Directorate Liaison Sub '
#                                          'Councils'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70010475&Department=70010483&Branch=70002011',
#                                  'name': 'Service Coordination And Logistics'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70010475&Department=70010483',
#                    'name': 'Support Services (Um)'},
#                   {'branches': [],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70010475&Department=70002800',
#                    'name': 'Vpuu (Violence Prevention Through Urban '
#                            'Upgrading)'}],
#   'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Departments.aspx?Directorate=70010475',
#   'name': 'Urban Management'},
#  {'departments': [{'branches': [],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70001882&Department=70002427',
#                    'name': 'Finance (Wws)'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70004111&Branch=70015283',
#                                  'name': 'Water And Waste: Pmo'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70001882&Department=70004111',
#                    'name': 'Project Monitoring Unit'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000354',
#                                  'name': 'Cleansing'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000332',
#                                  'name': 'Collections'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70002419',
#                                  'name': 'Contract Management Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70002410',
#                                  'name': 'Disposal'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000420',
#                                  'name': 'Finance & Commercial (Solid Waste)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70010587',
#                                  'name': 'Hr Business Partner (Sw)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000414',
#                                  'name': 'Planning'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000421',
#                                  'name': 'Support Services Solid Waste'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000331&Branch=70000425',
#                                  'name': 'Technical Services'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70001882&Department=70000331',
#                    'name': 'Solid Waste Management'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70002009&Branch=70002693',
#                                  'name': 'Occupational Health & Safety '
#                                          '(Utility Services)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70002009&Branch=70006529',
#                                  'name': 'Service Integration'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70001882&Department=70002009',
#                    'name': 'Support Services (Wws)'},
#                   {'branches': [{'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70018451',
#                                  'name': 'Bulk Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70000206',
#                                  'name': 'Bulk Water'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70018453',
#                                  'name': 'Commercial Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70016477',
#                                  'name': 'Customer Services (Water)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70002404',
#                                  'name': 'Engineering & Asset Management'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70000327',
#                                  'name': 'Finance & Commercial Water & '
#                                          'Sanitation'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70008482',
#                                  'name': 'Hr Business Partner (Water & '
#                                          'Sanitation)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70010393',
#                                  'name': 'Informal Settlements Basic Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70010395',
#                                  'name': 'Programmes And Development'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70018452',
#                                  'name': 'Retail Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70000238',
#                                  'name': 'Reticulation'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70002558',
#                                  'name': 'Rivers, Stormwater & Catchment '
#                                          'Management'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70000306',
#                                  'name': 'Scientific Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70002409',
#                                  'name': 'Support Services (Water And '
#                                          'Sanitation)'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70018454',
#                                  'name': 'Technical Services'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70000222',
#                                  'name': 'Wastewater'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70002197',
#                                  'name': 'Water Demand Management'},
#                                 {'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Sections.aspx?Directorate=70001882&Department=70000205&Branch=70011705',
#                                  'name': 'Water Resilience Project'}],
#                    'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Branches.aspx?Directorate=70001882&Department=70000205',
#                    'name': 'Water And Sanitation Services'}],
#   'link': 'http://cityweb.capetown.gov.za/en/_layouts/CityDepartmentStructure.ListAndUI/./Departments.aspx?Directorate=70001882',
#   'name': 'Water And Waste'}]

# %%
for dd in directorate_dicts:
    del dd["link"]
    for dept_d in dd["departments"]:
        del dept_d["link"]
        for b in dept_d["branches"]:
            del b["link"]

# %%
json.dump(directorate_dicts, open("city_structure.json","w"))
